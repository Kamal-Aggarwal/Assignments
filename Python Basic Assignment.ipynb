# %%
### 1. Simple Message
message = "Hello World!"
print(message)
# Out:
# Hello World!

# %%
### 2. Changes the variable message
message = "I love India"
print(message)
message = "I love my country"
print(message)
# Out:
# I love India
# I love my country

# %%
### 3. Store a person's name
var = "Kamal"
print("Hello",var, ", would you like to learn Python today?")
var1 = input("Please enter your name:")
print("Hello",var1, ", would you like to learn Python today?")
# Out:
# Hello Kamal , would you like to learn Python today?
# Please enter your name: Rahul
# Hello Rahul , would you like to learn Python today?

# %%
### 4. Famous person quote
person = "Lord Krishna"
print(person, 'once said, "Man is made by his belief."')
# Out:
# Lord Krishna once said, "Man is made by his belief."

# %%
### 5. Famous person variable
famous_person = "Lord Krishna"
quote = famous_person + ' once said, "Man is made by his belief."'
print(quote)
# Out:
# Lord Krishna once said, "Man is made by his belief."

# %%
### 6. Addition, Substraction, Multiplication, Division
print("Addition", 1+7)
print("Substraction", 10 - 2)
print("Multiplication", 2*4)
print("Divsion", int(24/3))
# Out:
# Addition 8
# Substraction 8
# Multiplication 8
# Divsion 8

# %%
### 7. Favourite Number
fav_number = 6
message2 = "My favourite number is - " + str(fav_number)
print(message2)
# Out:
# My favourite number is - 6

# %%
### 8. Adding comments to the program
from datetime import date
print("This is Kamal. I have written below program on ", date.today(), "This progam informs about my favourite number")
fav_number = 6
message2 = "My favourite number is - " + str(fav_number)
print(message2)
print("This is Kamal. I have written below program on ", date.today(), "This progam shows basic arithmetic operations")
print("Addition", 1+7)
print("Substraction", 10 - 2)
print("Multiplication", 2*4)
print("Divsion", int(24/3))
# Out:
# This is Kamal. I have written below program on  2025-10-04 This progam informs about my favourite number
# My favourite number is - 6
# This is Kamal. I have written below program on  2025-10-04 This progam shows basic arithmetic operations
# Addition 8
# Substraction 8
# Multiplication 8
# Divsion 8

# %%
### 9. Friends List
names = ['Chhaya', 'Aayush', 'Arnika', 'Mohit']
print("1st Friend - ", names[0])
print("2nd Friend - ", names[1])
print("3rd Friend - ", names[2])
print("4th Friend - ", names[3])
# Out:
# 1st Friend -  Chhaya
# 2nd Friend -  Aayush
# 3rd Friend -  Arnika
# 4th Friend -  Mohit

# %%
### 10. Personalized message
print("You are my life - ", names[0])
print("Both of you are my lifelines - ", names[1] , ",", names[2])
print("You are a friend - ", names[3])
# Out:
# You are my life -  Chhaya
# Both of you are my lifelines -  Aayush , Arnika
# You are a friend -  Mohit

# %%
### 11. Mode of Transportation
fav_transport = "Car"
l = ['Maruti', 'Honda', 'Toyota']
print("I drive ",l[0],"as it gives fuel efficiency")
print("I like to drive", l[1], "because of overall car ratings")
print("however", l[2], " is best")
# Out:
# I drive  Maruti as it gives fuel efficiency
# I like to drive Honda because of overall car ratings
# however Toyota  is best
